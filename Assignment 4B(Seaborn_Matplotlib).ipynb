# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\aman mujawar\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aman mujawar\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aman mujawar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\aman mujawar\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ## 1st ForestFire Dataset

# %%
import pandas as pd

# %%
data1 = pd.read_csv('forestfires.csv')

# %%
data1.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ## CountPlot

# %%
sb.countplot(data=data1, x='wind', palette='pastel')
# Out:
# C:\Users\Aman Mujawar\AppData\Local\Temp\ipykernel_8920\1781221081.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=data1, x='wind', palette='pastel')
# <Axes: xlabel='wind', ylabel='count'>

# %%
sb.countplot(data=data1, y='day', palette='pastel')
# Out:
# C:\Users\Aman Mujawar\AppData\Local\Temp\ipykernel_8920\3212717989.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=data1, y='day', palette='pastel')
# <Axes: xlabel='count', ylabel='day'>

# %%
data1.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
sb.countplot(data=data1, y='day', palette='pastel', hue='month')
plt.title('Countplot of Relative Humidity')
# Out:
# Text(0.5, 1.0, 'Countplot of Relative Humidity')

# %% [markdown]
# ## 2nd AirQuality Dataset

# %%
data2 = pd.read_csv('AirQuality.csv',delimiter=';')

# %%
data2.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# 0  0,7578          NaN          NaN
# 1  0,7255          NaN          NaN
# 2  0,7502          NaN          NaN
# 3  0,7867          NaN          NaN
# 4  0,7888          NaN          NaN

# %% [markdown]
# ## Histplot

# %%
data2.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
sb.histplot(data=data1, x='temp', hue='X')
plt.title('Histplot of Temperature')
# Out:
# Text(0.5, 1.0, 'Histplot of Temperature')

# %% [markdown]
# ## Boxenplot

# %%
sb.boxenplot(data=data2, x='T')
plt.title('Boxenplot of Relative Humidity')
# Out:
# Text(0.5, 1.0, 'Boxenplot of Relative Humidity')

# %% [markdown]
# ## Violineplot

# %%
sb.violinplot(
    data=data1,
    x='temp',
)
plt.title('Violinplot of Relative Humidity')
# Out:
# Text(0.5, 1.0, 'Violinplot of Relative Humidity')

# %% [markdown]
# ## Rugplot

# %%
sb.rugplot(data=data2, x='CO(GT)')
plt.title('Rugplot of CarbonMonoxide')
# Out:
# Text(0.5, 1.0, 'Rugplot of CarbonMonoxide')

# %% [markdown]
# ## Kdeplot

# %%
plt.title('Kdeplot of Temperature')
sb.kdeplot(data=data1, x='temp')
# Out:
# <Axes: title={'center': 'Kdeplot of CarbonMonoxide'}, xlabel='temp', ylabel='Density'>

# %%
plt.title('Kdeplot of Temperature')
sb.kdeplot(data=data1, x='temp', shade=True)
# Out:
# C:\Users\Aman Mujawar\AppData\Local\Temp\ipykernel_8920\762723972.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sb.kdeplot(data=data1, x='temp', shade=True)
# <Axes: title={'center': 'Kdeplot of CarbonMonoxide'}, xlabel='temp', ylabel='Density'>

# %%
plt.title('Kdeplot of Temperature')
sb.kdeplot(data=data1, x='temp', hue='day')
# Out:
# <Axes: title={'center': 'Kdeplot of Temperature'}, xlabel='temp', ylabel='Density'>

# %% [markdown]
# ## Stripplot

# %%
plt.title('Stripplot of Wind')
sb.stripplot(data=data1, x='wind')
# Out:
# <Axes: title={'center': 'Stripplot of Wind'}, xlabel='wind'>

# %% [markdown]
# ## Swarmplot

# %%
sb.swarmplot(data=data1, x='temp')
plt.title('Swarmplot of Temperature')
# Out:
# <Axes: xlabel='temp'>

# %% [markdown]
# ## Ecdfplot

# %%
sb.ecdfplot(data=data1, x='temp')
plt.title('ecdfplot of Temperature')
# Out:
# Text(0.5, 1.0, 'ecdfplot of Temperature')

# %%
sb.ecdfplot(data=data1, x='temp', hue='day')
plt.title('ecdfplot of Temperature')
# Out:
# Text(0.5, 1.0, 'ecdfplot of Temperature')
